# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from tensorflow import keras
import matplotlib.pyplot as plt
#from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import tensorflow as tf

# %%
df = pd.read_csv("row_size25_vector_size8000.csv")

# %%
for col in df.columns: 
    print(col)
# Out:
# time_change
# x_change
# y_change
# z_change
# phi_change
# theta_change
# psi_change
# accelerometer_reading_x_0
# accelerometer_reading_x_1
# accelerometer_reading_x_2
# accelerometer_reading_x_3
# accelerometer_reading_x_4
# accelerometer_reading_x_5
# accelerometer_reading_x_6
# accelerometer_reading_x_7
# accelerometer_reading_x_8
# accelerometer_reading_x_9
# accelerometer_reading_x_10
# accelerometer_reading_x_11
# accelerometer_reading_x_12
# accelerometer_reading_x_13
# accelerometer_reading_x_14
# accelerometer_reading_x_15
# accelerometer_reading_x_16
# accelerometer_reading_x_17
# accelerometer_reading_x_18
# accelerometer_reading_x_19
# accelerometer_reading_x_20
# accelerometer_reading_x_21
# accelerometer_reading_x_22
# accelerometer_reading_x_23
# accelerometer_reading_x_24
# accelerometer_reading_y_0
# accelerometer_reading_y_1
# accelerometer_reading_y_2
# accelerometer_reading_y_3
# accelerometer_reading_y_4
# accelerometer_reading_y_5
# accelerometer_reading_y_6
# accelerometer_reading_y_7
# accelerometer_reading_y_8
# accelerometer_reading_y_9
# accelerometer_reading_y_10
# accelerometer_reading_y_11
# accelerometer_reading_y_12
# accelerometer_reading_y_13
# accelerometer_reading_y_14
# accelerometer_reading_y_15
# accelerometer_reading_y_16
# accelerometer_reading_y_17
# accelerometer_reading_y_18
# accelerometer_reading_y_19
# accelerometer_reading_y_20
# accelerometer_reading_y_21
# accelerometer_reading_y_22
# accelerometer_reading_y_23
# accelerometer_reading_y_24
# accelerometer_reading_z_0
# accelerometer_reading_z_1
# accelerometer_reading_z_2
# accelerometer_reading_z_3
# accelerometer_reading_z_4
# accelerometer_reading_z_5
# accelerometer_reading_z_6
# accelerometer_reading_z_7
# accelerometer_reading_z_8
# accelerometer_reading_z_9
# accelerometer_reading_z_10
# accelerometer_reading_z_11
# accelerometer_reading_z_12
# accelerometer_reading_z_13
# accelerometer_reading_z_14
# accelerometer_reading_z_15
# accelerometer_reading_z_16
# accelerometer_reading_z_17
# accelerometer_reading_z_18
# accelerometer_reading_z_19
# accelerometer_reading_z_20
# accelerometer_reading_z_21
# accelerometer_reading_z_22
# accelerometer_reading_z_23
# accelerometer_reading_z_24
# gyroscope_reading_phi_0
# gyroscope_reading_phi_1
# gyroscope_reading_phi_2
# gyroscope_reading_phi_3
# gyroscope_reading_phi_4
# gyroscope_reading_phi_5
# gyroscope_reading_phi_6
# gyroscope_reading_phi_7
# gyroscope_reading_phi_8
# gyroscope_reading_phi_9
# gyroscope_reading_phi_10
# gyroscope_reading_phi_11
# gyroscope_reading_phi_12
# gyroscope_reading_phi_13
# gyroscope_reading_phi_14
# gyroscope_reading_phi_15
# gyroscope_reading_phi_16
# gyroscope_reading_phi_17
# gyroscope_reading_phi_18
# gyroscope_reading_phi_19
# gyroscope_reading_phi_20
# gyroscope_reading_phi_21
# gyroscope_reading_phi_22
# gyroscope_reading_phi_23
# gyroscope_reading_phi_24
# gyroscope_reading_theta_0
# gyroscope_reading_theta_1
# gyroscope_reading_theta_2
# gyroscope_reading_theta_3
# gyroscope_reading_theta_4
# gyroscope_reading_theta_5
# gyroscope_reading_theta_6
# gyroscope_reading_theta_7
# gyroscope_reading_theta_8
# gyroscope_reading_theta_9
# gyroscope_reading_theta_10
# gyroscope_reading_theta_11
# gyroscope_reading_theta_12
# gyroscope_reading_theta_13
# gyroscope_reading_theta_14
# gyroscope_reading_theta_15
# gyroscope_reading_theta_16
# gyroscope_reading_theta_17
# gyroscope_reading_theta_18
# gyroscope_reading_theta_19
# gyroscope_reading_theta_20
# gyroscope_reading_theta_21
# gyroscope_reading_theta_22
# gyroscope_reading_theta_23
# gyroscope_reading_theta_24
# gyroscope_reading_psi_0
# gyroscope_reading_psi_1
# gyroscope_reading_psi_2
# gyroscope_reading_psi_3
# gyroscope_reading_psi_4
# gyroscope_reading_psi_5
# gyroscope_reading_psi_6
# gyroscope_reading_psi_7
# gyroscope_reading_psi_8
# gyroscope_reading_psi_9
# gyroscope_reading_psi_10
# gyroscope_reading_psi_11
# gyroscope_reading_psi_12
# gyroscope_reading_psi_13
# gyroscope_reading_psi_14
# gyroscope_reading_psi_15
# gyroscope_reading_psi_16
# gyroscope_reading_psi_17
# gyroscope_reading_psi_18
# gyroscope_reading_psi_19
# gyroscope_reading_psi_20
# gyroscope_reading_psi_21
# gyroscope_reading_psi_22
# gyroscope_reading_psi_23
# gyroscope_reading_psi_24

# %%
X = df.iloc[:,7:157]




#X = df[['accelerometer_reading_x_0','accelerometer_reading_y_0','accelerometer_reading_z_0','gyroscope_reading_phi_0','gyroscope_reading_theta_0','gyroscope_reading_psi_0']]
#t = df[['linear_position_x','linear_position_y','linear_position_z','angular_position_phi','angular_position_theta','angular_position_psi']]

#t = df[['phi_change','theta_change','psi_change']]
t = df[['phi_change']]

# %%
X
# Out:
#       accelerometer_reading_x_0  accelerometer_reading_x_1  \
# 0                     -0.698110                   0.590438
# 1                     -0.099453                   0.061359
# 2                     -0.388588                   0.290145
# 3                     -1.071640                   0.640420
# 4                     -0.002145                   0.001609
# ...                         ...                        ...
# 7995                   0.344549                  -0.178680
# 7996                  -1.138212                   0.000950
# 7997                   0.356305                  -0.119151
# 7998                  -0.007634                  -0.005119
# 7999                   0.340826                  -0.348338
#
#       accelerometer_reading_x_2  accelerometer_reading_x_3  \
# 0                     -0.257626                   0.125631
# 1                     -0.033114                   0.028247
# 2                     -0.155464                   0.318173
# 3                     -0.366004                   0.212364
# 4                      0.000911                  -0.001406
# ...                         ...                        ...
# 7995                  -0.254628                   0.254226
# 7996                   0.150669                  -0.097780
# 7997                  -0.078508                  -0.045521
# 7998                   0.004320                   0.004603
# 7999                   0.170349                   0.001860
#
#       accelerometer_reading_x_4  accelerometer_reading_x_5  \
# 0                     -0.062696                   0.595336
# 1                     -0.017658                   0.072462
# 2                     -0.256355                   0.028242
# 3                      0.598898                  -0.598849
# 4                      0.001540                  -0.008721
# ...                         ...                        ...
# 7995                   0.596655                  -3.600011
# 7996                  -0.101460                  -0.030136
# 7997                   0.314906                  -0.230252
# 7998                  -0.004140                   0.022927
# 7999                  -0.178738                  -0.001779
#
#       accelerometer_reading_x_6  accelerometer_reading_x_7  \
# 0                     -0.444826                  -0.540315
# 1                     -0.123457                   0.070925
# 2                      0.130538                  -0.202318
# 3                     -0.511024                   1.131753
# 4                      0.011719                  -0.001178
# ...                         ...                        ...
# 7995                   3.001758                  -0.625824
# 7996                   1.282194                   0.000000
# 7997                  -0.070506                  -0.219769
# 7998                   0.006595                   0.002951
# 7999                   0.324358                  -0.449259
#
#       accelerometer_reading_x_8  accelerometer_reading_x_9  ...  \
# 0                      0.388053                   0.062870  ...
# 1                      0.073482                  -0.144182  ...
# 2                      0.211144                  -0.068916  ...
# 3                     -0.530478                  -0.223965  ...
# 4                     -0.010470                   0.010265  ...
# ...                         ...                        ...  ...
# 7995                   0.498295                   0.390806  ...
# 7996                  -1.169728                  -0.596613  ...
# 7997                   0.501185                  -0.201123  ...
# 7998                  -0.009726                   0.005135  ...
# 7999                   0.272544                   0.153352  ...
#
#       gyroscope_reading_psi_15  gyroscope_reading_psi_16  \
# 0                -8.800719e-03              5.298978e-03
# 1                -1.121775e-07             -5.435572e-09
# 2                 1.068992e-04              7.679180e-04
# 3                 2.090921e-02             -1.416385e-07
# 4                -1.160497e-05              9.331902e-06
# ...                        ...                       ...
# 7995             -2.722174e-08              1.567872e-07
# 7996              5.501784e-04              5.484273e-04
# 7997             -7.178587e-07              5.506110e-07
# 7998             -1.241202e-10             -1.330370e-10
# 7999             -3.415627e-08             -1.407230e-09
#
#       gyroscope_reading_psi_17  gyroscope_reading_psi_18  \
# 0                 9.884372e-03             -3.184273e-03
# 1                 1.052373e-07             -4.481473e-08
# 2                -5.237463e-03              5.592948e-03
# 3                 5.078921e-07              2.017139e-07
# 4                -2.339698e-07              7.108546e-06
# ...                        ...                       ...
# 7995              4.718872e-07             -6.411936e-07
# 7996              5.466180e-04              1.634981e-02
# 7997             -7.084310e-07              3.341495e-07
# 7998              3.279835e-10             -8.055880e-12
# 7999              6.688898e-08              3.118637e-06
#
#       gyroscope_reading_psi_19  gyroscope_reading_psi_20  \
# 0                -2.997938e-03              1.894689e-02
# 1                -1.186664e-07              2.082948e-07
# 2                 7.299841e-03              2.906117e-03
# 3                -6.800039e-07              8.511061e-07
# 4                -1.142023e-05              4.342353e-06
# ...                        ...                       ...
# 7995              5.316456e-08             -2.072972e-07
# 7996             -4.029324e-03             -1.339013e-02
# 7997              6.664534e-07              1.663469e-02
# 7998             -1.425668e-11             -1.963447e-10
# 7999              1.933207e-02             -9.572471e-06
#
#       gyroscope_reading_psi_21  gyroscope_reading_psi_22  \
# 0                 9.907016e-04              1.828426e-03
# 1                -1.504837e-07              1.285739e-07
# 2                -7.231721e-03              6.324463e-03
# 3                -6.071061e-07              4.289079e-07
# 4                 1.276205e-06             -2.418973e-07
# ...                        ...                       ...
# 7995              6.010984e-07              3.187830e-07
# 7996             -3.539107e-03              4.474886e-03
# 7997             -4.313218e-07              6.903582e-07
# 7998             -1.917192e-10              7.692665e-11
# 7999              1.701608e-09             -1.954218e-07
#
#       gyroscope_reading_psi_23  gyroscope_reading_psi_24
# 0                 1.944754e-03             -8.585624e-03
# 1                -1.430876e-07              5.696639e-08
# 2                -4.747468e-03              1.577196e-03
# 3                -6.729327e-07              1.772654e-07
# 4                 1.514210e-05             -1.567425e-05
# ...                        ...                       ...
# 7995             -1.177266e-06              5.136813e-07
# 7996             -2.388719e-02             -1.702367e-03
# 7997             -6.139961e-07             -2.495332e-07
# 7998              3.229322e-10             -1.307682e-10
# 7999              1.037532e-07             -3.418901e-08
#
# [8000 rows x 150 columns]

# %%
t.shape
# Out:
# (8000, 1)

# %%
in_dim = X.shape[1]
out_dim = t.shape[1]

# %%
X_train, X_test, t_train, t_test = train_test_split(X, t, test_size=0.2)

# %%
t_train.shape
# Out:
# (6400, 1)

# %%
model = Sequential()
model.add(Dense(256, input_dim=in_dim, activation="relu"))
model.add(Dense(128, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dense(out_dim))
model.compile(loss="mse", optimizer="adam")

# %%
#optimizer = keras.optimizers.Adam()
#lr_metric = get_lr_metric(optimizer)

#model.compile(
#    optimizer=optimizer,
#    metrics=['accuracy', lr_metric],
#    loss='mean_absolute_error', 
#    )

# %%
#model.evaluate(X_train, t_train, batch_size=12, verbose=2)

# %%
model.fit(X_train, t_train, epochs=60, batch_size=12, verbose=2)
# Out:
# Epoch 1/60
# 534/534 - 1s - loss: 1.3507
# Epoch 2/60
# 534/534 - 1s - loss: 3.1288
# Epoch 3/60
# 534/534 - 1s - loss: 353.5214
# Epoch 4/60
# 534/534 - 1s - loss: 154.5531
# Epoch 5/60
# 534/534 - 1s - loss: 48.6543
# Epoch 6/60
# 534/534 - 1s - loss: 1025.6921
# Epoch 7/60
# 534/534 - 1s - loss: 224.9704
# Epoch 8/60
# 534/534 - 1s - loss: 1496.0386
# Epoch 9/60
# 534/534 - 1s - loss: 113.3808
# Epoch 10/60
# 534/534 - 1s - loss: 558.1010
# Epoch 11/60
# 534/534 - 1s - loss: 755.4487
# Epoch 12/60
# 534/534 - 1s - loss: 111.9758
# Epoch 13/60
# 534/534 - 1s - loss: 141.9153
# Epoch 14/60
# 534/534 - 1s - loss: 1864.2347
# Epoch 15/60
# 534/534 - 1s - loss: 415.4167
# Epoch 16/60
# 534/534 - 1s - loss: 264.0095
# Epoch 17/60
# 534/534 - 1s - loss: 490.2069
# Epoch 18/60
# 534/534 - 1s - loss: 1592.2161
# Epoch 19/60
# 534/534 - 1s - loss: 762.9201
# Epoch 20/60
# 534/534 - 1s - loss: 221.9318
# Epoch 21/60
# 534/534 - 1s - loss: 83.1074
# Epoch 22/60
# 534/534 - 1s - loss: 100.9054
# Epoch 23/60
# 534/534 - 1s - loss: 197.9145
# Epoch 24/60
# 534/534 - 1s - loss: 72.6473
# Epoch 25/60
# 534/534 - 1s - loss: 49.6196
# Epoch 26/60
# 534/534 - 1s - loss: 34.2480
# Epoch 27/60
# 534/534 - 1s - loss: 14.3948
# Epoch 28/60
# 534/534 - 1s - loss: 18.0203
# Epoch 29/60
# 534/534 - 1s - loss: 32.1904
# Epoch 30/60
# 534/534 - 1s - loss: 69.3007
# Epoch 31/60
# 534/534 - 1s - loss: 126.8217
# Epoch 32/60
# 534/534 - 1s - loss: 7.7826
# Epoch 33/60
# 534/534 - 1s - loss: 6.5151
# Epoch 34/60
# 534/534 - 1s - loss: 34.8233
# Epoch 35/60
# 534/534 - 1s - loss: 5.4628
# Epoch 36/60
# 534/534 - 1s - loss: 0.4526
# Epoch 37/60
# 534/534 - 1s - loss: 4.7644
# Epoch 38/60
# 534/534 - 1s - loss: 4.0909
# Epoch 39/60
# 534/534 - 1s - loss: 8.1213
# Epoch 40/60
# 534/534 - 1s - loss: 0.3370
# Epoch 41/60
# 534/534 - 1s - loss: 2.3954
# Epoch 42/60
# 534/534 - 1s - loss: 0.7131
# Epoch 43/60
# 534/534 - 1s - loss: 0.1469
# Epoch 44/60
# 534/534 - 1s - loss: 0.3048
# Epoch 45/60
# 534/534 - 1s - loss: 0.0112
# Epoch 46/60
# 534/534 - 1s - loss: 0.0132
# Epoch 47/60
# 534/534 - 1s - loss: 0.0774
# Epoch 48/60
# 534/534 - 1s - loss: 0.0139
# Epoch 49/60
# 534/534 - 1s - loss: 0.4082
# Epoch 50/60
# 534/534 - 1s - loss: 0.2471
# Epoch 51/60
# 534/534 - 1s - loss: 0.0165
# Epoch 52/60
# 534/534 - 1s - loss: 0.2269
# Epoch 53/60
# 534/534 - 1s - loss: 0.0766
# Epoch 54/60
# 534/534 - 1s - loss: 1.1873
# Epoch 55/60
# 534/534 - 1s - loss: 23.6206
# Epoch 56/60
# 534/534 - 1s - loss: 33.9745
# Epoch 57/60
# 534/534 - 1s - loss: 22.5734
# Epoch 58/60
# 534/534 - 1s - loss: 0.0835
# Epoch 59/60
# 534/534 - 1s - loss: 4.3725e-05
# Epoch 60/60
# 534/534 - 1s - loss: 5.7467e-06

# %%
ypred = model.predict(X_test)
print("y1 MSE: ", mean_squared_error(t_test.iloc[:, 0], ypred[:,0])) 
#print("y2 MSE: ", mean_squared_error(t_test.iloc[:, 1], ypred[:,1]))
#print("y3 MSE: ", mean_squared_error(t_test.iloc[:, 2], ypred[:,2]))
# Out:
# y1 MSE:  3.7551272988040634e-06

# %%
x_ax = range(len(X_test))

plt.scatter(x_ax, t_test.iloc[:, 0],  s=6, label="y1-test")
plt.scatter(x_ax, ypred[:,0], label="y1-pred",c="red",alpha = 0.1)

plt.legend()
plt.show()

# %%
plt.scatter(x_ax, t_test.iloc[:, 1],  s=6, label="y2-test")
plt.scatter(x_ax, ypred[:,1], label="y2-pred",c="red",alpha = 0.1)

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-3c8e640e298c> in <module>
# ----> 1 plt.scatter(x_ax, t_test.iloc[:, 1],  s=6, label="y2-test")
#       2 plt.scatter(x_ax, ypred[:,1], label="y2-pred",c="red",alpha = 0.1)
#       3
#       4 plt.legend()
#       5 plt.show()
#
# ~\anaconda3\envs\ML\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~\anaconda3\envs\ML\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1441     def _getitem_tuple(self, tup: Tuple):
#    1442
# -> 1443         self._has_valid_tuple(tup)
#    1444         try:
#    1445             return self._getitem_lowerdim(tup)
#
# ~\anaconda3\envs\ML\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     700                 raise IndexingError("Too many indexers")
#     701             try:
# --> 702                 self._validate_key(k, i)
#     703             except ValueError as err:
#     704                 raise ValueError(
#
# ~\anaconda3\envs\ML\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1350             return
#    1351         elif is_integer(key):
# -> 1352             self._validate_integer(key, axis)
#    1353         elif isinstance(key, tuple):
#    1354             # a tuple should already have been caught by this point
#
# ~\anaconda3\envs\ML\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1435         len_axis = len(self.obj._get_axis(axis))
#    1436         if key >= len_axis or key < -len_axis:
# -> 1437             raise IndexError("single positional indexer is out-of-bounds")
#    1438
#    1439     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
plt.scatter(x_ax, t_test.iloc[:, 2],  s=6, label="y3-test")
plt.scatter(x_ax, ypred[:,2], label="y3-pred",c="red",alpha = 0.1)

plt.legend()
plt.show()

# %%
ypred
# Out:
# array([[0.00130219],
#        [0.00183121],
#        [0.00130219],
#        ...,
#        [0.00130219],
#        [0.00164774],
#        [0.00130219]], dtype=float32)

# %%
t_test
# Out:
#         phi_change
# 7916 -4.226158e-11
# 3697  1.191085e-06
# 7738  1.898834e-04
# 3652 -6.226942e-05
# 6322  1.195585e-11
# ...            ...
# 4413  6.316768e-04
# 3360 -2.813372e-06
# 3300 -4.687686e-09
# 6073  5.201071e-07
# 426  -5.646838e-05
#
# [1600 rows x 1 columns]

# %%
m = tf.keras.metrics.AUC(num_thresholds=3)
m.update_state(t_test,ypred)
m.result().numpy()
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-36-8706ff5879e7> in <module>
#       1 m = tf.keras.metrics.AUC(num_thresholds=3)
# ----> 2 m.update_state(t_test,ypred)
#       3 m.result().numpy()
#
# ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\keras\utils\metrics_utils.py in decorated(metric_obj, *args, **kwargs)
#      88
#      89     with tf_utils.graph_context_for_symbolic_tensors(*args, **kwargs):
# ---> 90       update_op = update_state_fn(*args, **kwargs)
#      91     if update_op is not None:  # update_op will be None in eager execution.
#      92       metric_obj.add_update(update_op)
#
# ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\keras\metrics.py in update_state_fn(*args, **kwargs)
#     174         control_status = ag_ctx.control_status_ctx()
#     175         ag_update_state = autograph.tf_convert(obj_update_state, control_status)
# --> 176         return ag_update_state(*args, **kwargs)
#     177     else:
#     178       if isinstance(obj.update_state, def_function.Function):
#
# ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\autograph\impl\api.py in wrapper(*args, **kwargs)
#     253       try:
#     254         with conversion_ctx:
# --> 255           return converted_call(f, args, kwargs, options=options)
#     256       except Exception as e:  # pylint:disable=broad-except
#     257         if hasattr(e, 'ag_error_metadata'):
#
# ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     530
#     531   if not options.user_requested and conversion.is_whitelisted(f):
# --> 532     return _call_unconverted(f, args, kwargs, options)
#     533
#     534   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\autograph\impl\api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     337
#     338   if kwargs is not None:
# --> 339     return f(*args, **kwargs)
#     340   return f(*args)
#     341
#
# ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\keras\metrics.py in update_state(self, y_true, y_pred, sample_weight)
#    2067     label_weights = None if self.multi_label else self.label_weights
#    2068     with ops.control_dependencies(deps):
# -> 2069       return metrics_utils.update_confusion_matrix_variables(
#    2070           {
#    2071               metrics_utils.ConfusionMatrix.TRUE_POSITIVES:
#
# ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\keras\utils\metrics_utils.py in update_confusion_matrix_variables(variables_to_update, y_true, y_pred, thresholds, top_k, class_id, sample_weight, multi_label, label_weights)
#     334
#     335   with ops.control_dependencies([
# --> 336       check_ops.assert_greater_equal(
#     337           y_pred,
#     338           math_ops.cast(0.0, dtype=y_pred.dtype),
#
# ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\ops\check_ops.py in assert_greater_equal(x, y, data, summarize, message, name)
#    1037 def assert_greater_equal(x, y, data=None, summarize=None, message=None,
#    1038                          name=None):
# -> 1039   return _binary_assert('>=', 'assert_greater_equal', math_ops.greater_equal,
#    1040                         np.greater_equal, x, y, data, summarize, message, name)
#    1041
#
# ~\anaconda3\envs\ML\lib\site-packages\tensorflow\python\ops\check_ops.py in _binary_assert(sym, opname, op_func, static_func, x, y, data, summarize, message, name)
#     351         data = [message] + list(data)
#     352
# --> 353       raise errors.InvalidArgumentError(
#     354           node_def=None,
#     355           op=None,
#
# InvalidArgumentError: predictions must be >= 0
# Condition x >= y did not hold.
# First 3 elements of x:
# [0.00130219 0.00183121 0.00130219]
# First 1 elements of y:
# [0.]
