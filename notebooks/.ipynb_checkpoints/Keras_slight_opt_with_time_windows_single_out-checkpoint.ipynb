# %%
import pandas as pd
from keras.models import Sequential
#from keras.layers import Dense
from tensorflow.keras.layers import Input, Dense, Activation,Dropout
from sklearn.model_selection import train_test_split
from tensorflow import keras
import matplotlib.pyplot as plt
#from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import tensorflow as tf
import numpy as np

# %%
df = pd.read_csv("row_size25_vector_size8000.csv")

# %%
#df = df * 1000
df
# Out:
#       time_change  x_change      y_change      z_change  phi_change  \
# 0            0.75  0.095414  7.831732e-04 -1.830826e-02    0.000004
# 1            0.75  0.014835  6.554644e-08 -5.668671e-07   -0.000100
# 2            0.75  0.038542 -4.253019e-02 -1.324112e+00   -0.000565
# 3            0.75  0.089380  8.486856e-02  2.985025e-03    0.000001
# 4            0.75 -0.000740 -7.529482e-03  1.489150e-03   -0.000005
# ...           ...       ...           ...           ...         ...
# 7995         0.75  0.080613 -5.670724e-02  3.395028e-03   -0.000898
# 7996         0.75 -0.031717  8.451793e-02  5.029793e-01    0.000211
# 7997         0.75 -0.048495 -5.835063e-02  9.999901e-03    0.000474
# 7998         0.75  0.001300  6.367301e-03 -2.180824e-03    0.000004
# 7999         0.75 -0.082590  7.840401e-02 -2.508021e-01   -0.000045
#
#       theta_change    psi_change  accelerometer_reading_x_0  \
# 0    -1.899489e-05  8.611218e-04                  -0.698110
# 1     9.376077e-11  1.925615e-08                  -0.099453
# 2     5.260375e-04 -9.803592e-04                  -0.388588
# 3     1.303843e-06  1.148772e-07                  -1.071640
# 4     2.239492e-05  2.292067e-06                  -0.002145
# ...            ...           ...                        ...
# 7995  5.510571e-04 -1.511662e-08                   0.344549
# 7996  5.391571e-05 -4.915356e-03                  -1.138212
# 7997  5.505674e-04 -8.582078e-08                   0.356305
# 7998 -1.811738e-05  4.211093e-12                  -0.007634
# 7999  4.076486e-05  1.285518e-08                   0.340826
#
#       accelerometer_reading_x_1  accelerometer_reading_x_2  ...  \
# 0                      0.590438                  -0.257626  ...
# 1                      0.061359                  -0.033114  ...
# 2                      0.290145                  -0.155464  ...
# 3                      0.640420                  -0.366004  ...
# 4                      0.001609                   0.000911  ...
# ...                         ...                        ...  ...
# 7995                  -0.178680                  -0.254628  ...
# 7996                   0.000950                   0.150669  ...
# 7997                  -0.119151                  -0.078508  ...
# 7998                  -0.005119                   0.004320  ...
# 7999                  -0.348338                   0.170349  ...
#
#       gyroscope_reading_psi_15  gyroscope_reading_psi_16  \
# 0                -8.800719e-03              5.298978e-03
# 1                -1.121775e-07             -5.435572e-09
# 2                 1.068992e-04              7.679180e-04
# 3                 2.090921e-02             -1.416385e-07
# 4                -1.160497e-05              9.331902e-06
# ...                        ...                       ...
# 7995             -2.722174e-08              1.567872e-07
# 7996              5.501784e-04              5.484273e-04
# 7997             -7.178587e-07              5.506110e-07
# 7998             -1.241202e-10             -1.330370e-10
# 7999             -3.415627e-08             -1.407230e-09
#
#       gyroscope_reading_psi_17  gyroscope_reading_psi_18  \
# 0                 9.884372e-03             -3.184273e-03
# 1                 1.052373e-07             -4.481473e-08
# 2                -5.237463e-03              5.592948e-03
# 3                 5.078921e-07              2.017139e-07
# 4                -2.339698e-07              7.108546e-06
# ...                        ...                       ...
# 7995              4.718872e-07             -6.411936e-07
# 7996              5.466180e-04              1.634981e-02
# 7997             -7.084310e-07              3.341495e-07
# 7998              3.279835e-10             -8.055880e-12
# 7999              6.688898e-08              3.118637e-06
#
#       gyroscope_reading_psi_19  gyroscope_reading_psi_20  \
# 0                -2.997938e-03              1.894689e-02
# 1                -1.186664e-07              2.082948e-07
# 2                 7.299841e-03              2.906117e-03
# 3                -6.800039e-07              8.511061e-07
# 4                -1.142023e-05              4.342353e-06
# ...                        ...                       ...
# 7995              5.316456e-08             -2.072972e-07
# 7996             -4.029324e-03             -1.339013e-02
# 7997              6.664534e-07              1.663469e-02
# 7998             -1.425668e-11             -1.963447e-10
# 7999              1.933207e-02             -9.572471e-06
#
#       gyroscope_reading_psi_21  gyroscope_reading_psi_22  \
# 0                 9.907016e-04              1.828426e-03
# 1                -1.504837e-07              1.285739e-07
# 2                -7.231721e-03              6.324463e-03
# 3                -6.071061e-07              4.289079e-07
# 4                 1.276205e-06             -2.418973e-07
# ...                        ...                       ...
# 7995              6.010984e-07              3.187830e-07
# 7996             -3.539107e-03              4.474886e-03
# 7997             -4.313218e-07              6.903582e-07
# 7998             -1.917192e-10              7.692665e-11
# 7999              1.701608e-09             -1.954218e-07
#
#       gyroscope_reading_psi_23  gyroscope_reading_psi_24
# 0                 1.944754e-03             -8.585624e-03
# 1                -1.430876e-07              5.696639e-08
# 2                -4.747468e-03              1.577196e-03
# 3                -6.729327e-07              1.772654e-07
# 4                 1.514210e-05             -1.567425e-05
# ...                        ...                       ...
# 7995             -1.177266e-06              5.136813e-07
# 7996             -2.388719e-02             -1.702367e-03
# 7997             -6.139961e-07             -2.495332e-07
# 7998              3.229322e-10             -1.307682e-10
# 7999              1.037532e-07             -3.418901e-08
#
# [8000 rows x 157 columns]

# %%
#for col in df.columns: 
#    print(col)

# %%
X = df.iloc[:,7:157]




#X = df[['accelerometer_reading_x_0','accelerometer_reading_y_0','accelerometer_reading_z_0','gyroscope_reading_phi_0','gyroscope_reading_theta_0','gyroscope_reading_psi_0']]
#t = df[['linear_position_x','linear_position_y','linear_position_z','angular_position_phi','angular_position_theta','angular_position_psi']]

#t = df[['phi_change','theta_change','psi_change']]
t = df[['phi_change']]

#t = df[['theta_change']]
#t = df[['psi_change']]

# %%
X
# Out:
#       accelerometer_reading_x_0  accelerometer_reading_x_1  \
# 0                     -0.698110                   0.590438
# 1                     -0.099453                   0.061359
# 2                     -0.388588                   0.290145
# 3                     -1.071640                   0.640420
# 4                     -0.002145                   0.001609
# ...                         ...                        ...
# 7995                   0.344549                  -0.178680
# 7996                  -1.138212                   0.000950
# 7997                   0.356305                  -0.119151
# 7998                  -0.007634                  -0.005119
# 7999                   0.340826                  -0.348338
#
#       accelerometer_reading_x_2  accelerometer_reading_x_3  \
# 0                     -0.257626                   0.125631
# 1                     -0.033114                   0.028247
# 2                     -0.155464                   0.318173
# 3                     -0.366004                   0.212364
# 4                      0.000911                  -0.001406
# ...                         ...                        ...
# 7995                  -0.254628                   0.254226
# 7996                   0.150669                  -0.097780
# 7997                  -0.078508                  -0.045521
# 7998                   0.004320                   0.004603
# 7999                   0.170349                   0.001860
#
#       accelerometer_reading_x_4  accelerometer_reading_x_5  \
# 0                     -0.062696                   0.595336
# 1                     -0.017658                   0.072462
# 2                     -0.256355                   0.028242
# 3                      0.598898                  -0.598849
# 4                      0.001540                  -0.008721
# ...                         ...                        ...
# 7995                   0.596655                  -3.600011
# 7996                  -0.101460                  -0.030136
# 7997                   0.314906                  -0.230252
# 7998                  -0.004140                   0.022927
# 7999                  -0.178738                  -0.001779
#
#       accelerometer_reading_x_6  accelerometer_reading_x_7  \
# 0                     -0.444826                  -0.540315
# 1                     -0.123457                   0.070925
# 2                      0.130538                  -0.202318
# 3                     -0.511024                   1.131753
# 4                      0.011719                  -0.001178
# ...                         ...                        ...
# 7995                   3.001758                  -0.625824
# 7996                   1.282194                   0.000000
# 7997                  -0.070506                  -0.219769
# 7998                   0.006595                   0.002951
# 7999                   0.324358                  -0.449259
#
#       accelerometer_reading_x_8  accelerometer_reading_x_9  ...  \
# 0                      0.388053                   0.062870  ...
# 1                      0.073482                  -0.144182  ...
# 2                      0.211144                  -0.068916  ...
# 3                     -0.530478                  -0.223965  ...
# 4                     -0.010470                   0.010265  ...
# ...                         ...                        ...  ...
# 7995                   0.498295                   0.390806  ...
# 7996                  -1.169728                  -0.596613  ...
# 7997                   0.501185                  -0.201123  ...
# 7998                  -0.009726                   0.005135  ...
# 7999                   0.272544                   0.153352  ...
#
#       gyroscope_reading_psi_15  gyroscope_reading_psi_16  \
# 0                -8.800719e-03              5.298978e-03
# 1                -1.121775e-07             -5.435572e-09
# 2                 1.068992e-04              7.679180e-04
# 3                 2.090921e-02             -1.416385e-07
# 4                -1.160497e-05              9.331902e-06
# ...                        ...                       ...
# 7995             -2.722174e-08              1.567872e-07
# 7996              5.501784e-04              5.484273e-04
# 7997             -7.178587e-07              5.506110e-07
# 7998             -1.241202e-10             -1.330370e-10
# 7999             -3.415627e-08             -1.407230e-09
#
#       gyroscope_reading_psi_17  gyroscope_reading_psi_18  \
# 0                 9.884372e-03             -3.184273e-03
# 1                 1.052373e-07             -4.481473e-08
# 2                -5.237463e-03              5.592948e-03
# 3                 5.078921e-07              2.017139e-07
# 4                -2.339698e-07              7.108546e-06
# ...                        ...                       ...
# 7995              4.718872e-07             -6.411936e-07
# 7996              5.466180e-04              1.634981e-02
# 7997             -7.084310e-07              3.341495e-07
# 7998              3.279835e-10             -8.055880e-12
# 7999              6.688898e-08              3.118637e-06
#
#       gyroscope_reading_psi_19  gyroscope_reading_psi_20  \
# 0                -2.997938e-03              1.894689e-02
# 1                -1.186664e-07              2.082948e-07
# 2                 7.299841e-03              2.906117e-03
# 3                -6.800039e-07              8.511061e-07
# 4                -1.142023e-05              4.342353e-06
# ...                        ...                       ...
# 7995              5.316456e-08             -2.072972e-07
# 7996             -4.029324e-03             -1.339013e-02
# 7997              6.664534e-07              1.663469e-02
# 7998             -1.425668e-11             -1.963447e-10
# 7999              1.933207e-02             -9.572471e-06
#
#       gyroscope_reading_psi_21  gyroscope_reading_psi_22  \
# 0                 9.907016e-04              1.828426e-03
# 1                -1.504837e-07              1.285739e-07
# 2                -7.231721e-03              6.324463e-03
# 3                -6.071061e-07              4.289079e-07
# 4                 1.276205e-06             -2.418973e-07
# ...                        ...                       ...
# 7995              6.010984e-07              3.187830e-07
# 7996             -3.539107e-03              4.474886e-03
# 7997             -4.313218e-07              6.903582e-07
# 7998             -1.917192e-10              7.692665e-11
# 7999              1.701608e-09             -1.954218e-07
#
#       gyroscope_reading_psi_23  gyroscope_reading_psi_24
# 0                 1.944754e-03             -8.585624e-03
# 1                -1.430876e-07              5.696639e-08
# 2                -4.747468e-03              1.577196e-03
# 3                -6.729327e-07              1.772654e-07
# 4                 1.514210e-05             -1.567425e-05
# ...                        ...                       ...
# 7995             -1.177266e-06              5.136813e-07
# 7996             -2.388719e-02             -1.702367e-03
# 7997             -6.139961e-07             -2.495332e-07
# 7998              3.229322e-10             -1.307682e-10
# 7999              1.037532e-07             -3.418901e-08
#
# [8000 rows x 150 columns]

# %%
t.shape
# Out:
# (8000, 1)

# %%
in_dim = X.shape[1]
out_dim = t.shape[1]

# %%
X_train, X_test, t_train, t_test = train_test_split(X, t, test_size=0.2)

# %%
t_train.shape
# Out:
# (6400, 1)

# %%
model = Sequential()
model.add(Dense(256, input_dim=in_dim, activation="relu"))
model.add(Dense(128, activation="sigmoid"))
model.add(Dense(64, activation="softmax"))
model.add(Dense(out_dim))
#model.compile(loss="mse", optimizer="adam")
model.compile(loss="mse", optimizer="sgd")

# %%
#optimizer = keras.optimizers.Adam()
#lr_metric = get_lr_metric(optimizer)

#model.compile(
#    optimizer=optimizer,
#    metrics=['accuracy', lr_metric],
#    loss='mean_absolute_error', 
#    )

# %%
#model.evaluate(X_train, t_train, batch_size=12, verbose=2)

# %%
model.fit(X_train, t_train, epochs=30, batch_size=2, verbose=2, validation_split=0.4)
# Out:
# Epoch 1/30
# 1920/1920 - 4s - loss: 1.1517e-05 - val_loss: 1.0775e-05
# Epoch 2/30
# 1920/1920 - 3s - loss: 1.0730e-05 - val_loss: 1.0732e-05
# Epoch 3/30
# 1920/1920 - 3s - loss: 1.0538e-05 - val_loss: 1.0413e-05
# Epoch 4/30
# 1920/1920 - 4s - loss: 1.0307e-05 - val_loss: 1.0281e-05
# Epoch 5/30
# 1920/1920 - 4s - loss: 1.0106e-05 - val_loss: 1.0078e-05
# Epoch 6/30
# 1920/1920 - 4s - loss: 9.9035e-06 - val_loss: 1.0120e-05
# Epoch 7/30
# 1920/1920 - 4s - loss: 9.7046e-06 - val_loss: 1.0086e-05
# Epoch 8/30
# 1920/1920 - 5s - loss: 9.5217e-06 - val_loss: 9.7040e-06
# Epoch 9/30
# 1920/1920 - 4s - loss: 9.3700e-06 - val_loss: 9.5350e-06
# Epoch 10/30
# 1920/1920 - 3s - loss: 9.2110e-06 - val_loss: 9.4324e-06
# Epoch 11/30
# 1920/1920 - 3s - loss: 9.0720e-06 - val_loss: 9.3547e-06
# Epoch 12/30
# 1920/1920 - 4s - loss: 8.9181e-06 - val_loss: 9.2590e-06
# Epoch 13/30
# 1920/1920 - 3s - loss: 8.7720e-06 - val_loss: 9.1985e-06
# Epoch 14/30
# 1920/1920 - 4s - loss: 8.6608e-06 - val_loss: 8.9846e-06
# Epoch 15/30
# 1920/1920 - 3s - loss: 8.5374e-06 - val_loss: 8.8893e-06
# Epoch 16/30
# 1920/1920 - 3s - loss: 8.4090e-06 - val_loss: 8.8312e-06
# Epoch 17/30
# 1920/1920 - 3s - loss: 8.2958e-06 - val_loss: 8.7177e-06
# Epoch 18/30
# 1920/1920 - 3s - loss: 8.1713e-06 - val_loss: 8.6349e-06
# Epoch 19/30
# 1920/1920 - 4s - loss: 8.0809e-06 - val_loss: 8.5916e-06
# Epoch 20/30
# 1920/1920 - 4s - loss: 8.0066e-06 - val_loss: 8.4840e-06
# Epoch 21/30
# 1920/1920 - 5s - loss: 7.9075e-06 - val_loss: 8.4412e-06
# Epoch 22/30
# 1920/1920 - 4s - loss: 7.8095e-06 - val_loss: 8.3552e-06
# Epoch 23/30
# 1920/1920 - 4s - loss: 7.7081e-06 - val_loss: 8.2930e-06
# Epoch 24/30
# 1920/1920 - 4s - loss: 7.6357e-06 - val_loss: 8.2136e-06
# Epoch 25/30
# 1920/1920 - 5s - loss: 7.5692e-06 - val_loss: 8.1813e-06
# Epoch 26/30
# 1920/1920 - 5s - loss: 7.4809e-06 - val_loss: 8.2044e-06
# Epoch 27/30
# 1920/1920 - 5s - loss: 7.4150e-06 - val_loss: 8.0366e-06
# Epoch 28/30
# 1920/1920 - 4s - loss: 7.3419e-06 - val_loss: 7.9896e-06
# Epoch 29/30
# 1920/1920 - 3s - loss: 7.2859e-06 - val_loss: 7.9290e-06
# Epoch 30/30
# 1920/1920 - 4s - loss: 7.2099e-06 - val_loss: 7.9531e-06

# %%
ypred = model.predict(X_test)
print("y1 MSE: ", np.sqrt(mean_squared_error(t_test.iloc[:, 0], ypred[:,0])))
#print("y2 MSE: ", mean_squared_error(t_test.iloc[:, 1], ypred[:,1]))
#print("y3 MSE: ", mean_squared_error(t_test.iloc[:, 2], ypred[:,2]))
# Out:
# y1 MSE:  0.0027875140155022428

# %%
x_ax = range(len(X_test))

plt.scatter(x_ax, t_test.iloc[:, 0],  s=6, label="y1-test")
plt.scatter(x_ax, ypred[:,0],s = 6, label="y1-pred",c="red",alpha = 0.5)

plt.legend()
plt.show()

# %%
ypred
# Out:
# array([[-0.01135624],
#        [-0.00031444],
#        [-0.00021471],
#        ...,
#        [-0.00015595],
#        [ 0.00881072],
#        [ 0.00038304]], dtype=float32)

# %%
t_test

# %%
m = tf.keras.metrics.AUC(num_thresholds=3)
m.update_state(t_test,ypred)
m.result().numpy()
